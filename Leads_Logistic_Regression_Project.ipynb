# %%
import pandas as pd 
leads = pd.read_csv("Leads.csv")
leads.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# ...

# %%
leads.shape
# Out:
# (9240, 37)

# %%
leads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 37 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Prospect ID                                    9240 non-null   object
#  1   Lead Number                                    9240 non-null   int64
#  2   Lead Origin                                    9240 non-null   object
#  3   Lead Source                                    9204 non-null   object
#  4   Do Not Email                                   9240 non-null   object
#  5   Do Not Call                                    9240 non-null   object
#  6   Converted                                      9240 non-null   int64
#  7   TotalVisits                                    9103 non-null   float64
#  8   Total Time Spent on Website                    9240 non-null   int64
# ...

# %%
leads.describe()
# Out:
#          Lead Number    Converted  TotalVisits  Total Time Spent on Website  \
# count    9240.000000  9240.000000  9103.000000                  9240.000000
# mean   617188.435606     0.385390     3.445238                   487.698268
# std     23405.995698     0.486714     4.854853                   548.021466
# min    579533.000000     0.000000     0.000000                     0.000000
# 25%    596484.500000     0.000000     1.000000                    12.000000
# 50%    615479.000000     0.000000     3.000000                   248.000000
# 75%    637387.250000     1.000000     5.000000                   936.000000
# max    660737.000000     1.000000   251.000000                  2272.000000
#
#        Page Views Per Visit  Asymmetrique Activity Score  \
# count           9103.000000                  5022.000000
# mean               2.362820                    14.306252
# std                2.161418                     1.386694
# ...

# %%
leads.describe(include='object')
# Out:
#                                  Prospect ID              Lead Origin  \
# count                                   9240                     9240
# unique                                  9240                        5
# top     571b5c8e-a5b2-4d57-8574-f2ffb06fdeff  Landing Page Submission
# freq                                       1                     4886
#
#        Lead Source Do Not Email Do Not Call Last Activity Country  \
# count         9204         9240        9240          9137    6779
# unique          21            2           2            17      38
# top         Google           No          No  Email Opened   India
# freq          2868         8506        9238          3437    6492
#
#        Specialization How did you hear about X Education  \
# count            7802                               7033
# unique             19                                 10
# top            Select                             Select
# ...

# %%
round((leads.isnull().sum()/len(leads))*100,2)
# Out:
# Prospect ID                                       0.00
# Lead Number                                       0.00
# Lead Origin                                       0.00
# Lead Source                                       0.39
# Do Not Email                                      0.00
# Do Not Call                                       0.00
# Converted                                         0.00
# TotalVisits                                       1.48
# Total Time Spent on Website                       0.00
# Page Views Per Visit                              1.48
# Last Activity                                     1.11
# Country                                          26.63
# Specialization                                   15.56
# How did you hear about X Education               23.89
# What is your current occupation                  29.11
# What matters most to you in choosing a course    29.32
# Search                                            0.00
# ...

# %%
leads.isnull().sum()
# Out:
# Prospect ID                                         0
# Lead Number                                         0
# Lead Origin                                         0
# Lead Source                                        36
# Do Not Email                                        0
# Do Not Call                                         0
# Converted                                           0
# TotalVisits                                       137
# Total Time Spent on Website                         0
# Page Views Per Visit                              137
# Last Activity                                     103
# Country                                          2461
# Specialization                                   1438
# How did you hear about X Education               2207
# What is your current occupation                  2690
# What matters most to you in choosing a course    2709
# Search                                              0
# ...

# %%
(round((leads.isnull().sum()/
len(leads))*100,2)).sort_values(ascending=False)
# Out:
# Lead Quality                                     51.59
# Asymmetrique Profile Index                       45.65
# Asymmetrique Activity Score                      45.65
# Asymmetrique Activity Index                      45.65
# Asymmetrique Profile Score                       45.65
# Tags                                             36.29
# What matters most to you in choosing a course    29.32
# Lead Profile                                     29.32
# What is your current occupation                  29.11
# Country                                          26.63
# How did you hear about X Education               23.89
# Specialization                                   15.56
# City                                             15.37
# Page Views Per Visit                              1.48
# TotalVisits                                       1.48
# Last Activity                                     1.11
# Lead Source                                       0.39
# ...

# %%
cols = ['Prospect ID','Lead Number']
leads = leads.drop(cols,axis=1)

# %%
leads.shape
# Out:
# (9240, 35)

# %%
leads.shape
# Out:
# (9240, 35)

# %%
cols_to_drop = ['Lead Quality','Asymmetrique Profile Index','Asymmetrique Activity Score','Asymmetrique Activity Index','Asymmetrique Profile Score']
leads = leads.drop(cols_to_drop, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 2
#       1 cols_to_drop = ['Lead Quality','Asymmetrique Profile Index','Asymmetrique Activity Score','Asymmetrique Activity Index','Asymmetrique Profile Score']
# ----> 2 leads = leads.drop(cols_to_drop, axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
# ...

# %%
leads.columns
# Out:
# Index(['Lead Origin', 'Lead Source', 'Do Not Email', 'Do Not Call',
#        'Converted', 'TotalVisits', 'Total Time Spent on Website',
#        'Page Views Per Visit', 'Last Activity', 'Country', 'Specialization',
#        'How did you hear about X Education', 'What is your current occupation',
#        'What matters most to you in choosing a course', 'Search', 'Magazine',
#        'Newspaper Article', 'X Education Forums', 'Newspaper',
#        'Digital Advertisement', 'Through Recommendations',
#        'Receive More Updates About Our Courses', 'Tags',
#        'Update me on Supply Chain Content', 'Get updates on DM Content',
#        'Lead Profile', 'City', 'I agree to pay the amount through cheque',
#        'A free copy of Mastering The Interview', 'Last Notable Activity'],
#       dtype='object')

# %%
cols_to_drop = ['Lead Quality',
                'Asymmetrique Profile Index',
                'Asymmetrique Activity Score',
                'Asymmetrique Activity Index',
                'Asymmetrique Profile Score']

leads = leads.drop(cols_to_drop, axis=1, errors='ignore')

# %%
leads.shape
# Out:
# (9240, 30)

# %%
round((leads.isnull().sum()/
len(leads))*100,2).sort_values(ascending=False)
# Out:
# Tags                                             36.29
# What matters most to you in choosing a course    29.32
# Lead Profile                                     29.32
# What is your current occupation                  29.11
# Country                                          26.63
# How did you hear about X Education               23.89
# Specialization                                   15.56
# City                                             15.37
# Page Views Per Visit                              1.48
# TotalVisits                                       1.48
# Last Activity                                     1.11
# Lead Source                                       0.39
# Converted                                         0.00
# Lead Origin                                       0.00
# Total Time Spent on Website                       0.00
# Do Not Email                                      0.00
# Do Not Call                                       0.00
# ...

# %%
leads = leads[~pd.isnull(leads['Lead Profile'])]

# %%
leads.shape
# Out:
# (6531, 30)

# %%
round((leads.isnull().sum()/
len(leads))*100,2).sort_values(ascending=False)
# Out:
# Country                                          24.58
# Tags                                             11.10
# Page Views Per Visit                              1.99
# TotalVisits                                       1.99
# Last Activity                                     1.58
# Lead Source                                       0.55
# Converted                                         0.00
# Do Not Call                                       0.00
# Do Not Email                                      0.00
# Total Time Spent on Website                       0.00
# Specialization                                    0.00
# How did you hear about X Education                0.00
# What is your current occupation                   0.00
# Lead Origin                                       0.00
# What matters most to you in choosing a course     0.00
# Search                                            0.00
# Newspaper Article                                 0.00
# ...

# %%
leads = leads[~pd.isnull(leads['Country'])]

# %%
leads.shape
# Out:
# (4926, 30)

# %%
round((leads.isnull().sum()/len(leads))*100,2).sort_values(ascending=False)
# Out:
# Tags                                             7.94
# Lead Source                                      0.02
# Do Not Email                                     0.00
# Do Not Call                                      0.00
# Converted                                        0.00
# Lead Origin                                      0.00
# Total Time Spent on Website                      0.00
# Page Views Per Visit                             0.00
# Last Activity                                    0.00
# Country                                          0.00
# Specialization                                   0.00
# How did you hear about X Education               0.00
# What is your current occupation                  0.00
# TotalVisits                                      0.00
# What matters most to you in choosing a course    0.00
# Search                                           0.00
# Newspaper Article                                0.00
# ...

# %%
leads = leads[~pd.isnull(leads['Tags'])]

# %%
leads.shape
# Out:
# (4535, 30)

# %%
round((leads.isnull().sum()/len(leads))*100,2).sort_values(ascending=False)
# Out:
# Lead Source                                      0.02
# Lead Origin                                      0.00
# Do Not Email                                     0.00
# Do Not Call                                      0.00
# Converted                                        0.00
# TotalVisits                                      0.00
# Total Time Spent on Website                      0.00
# Page Views Per Visit                             0.00
# Last Activity                                    0.00
# Country                                          0.00
# Specialization                                   0.00
# How did you hear about X Education               0.00
# What is your current occupation                  0.00
# What matters most to you in choosing a course    0.00
# Search                                           0.00
# Magazine                                         0.00
# Newspaper Article                                0.00
# ...

# %%
leads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4535 entries, 1 to 9239
# Data columns (total 30 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Lead Origin                                    4535 non-null   object
#  1   Lead Source                                    4534 non-null   object
#  2   Do Not Email                                   4535 non-null   object
#  3   Do Not Call                                    4535 non-null   object
#  4   Converted                                      4535 non-null   int64
#  5   TotalVisits                                    4535 non-null   float64
#  6   Total Time Spent on Website                    4535 non-null   int64
#  7   Page Views Per Visit                           4535 non-null   float64
#  8   Last Activity                                  4535 non-null   object
# ...

# %%
varlist = ['Do Not Email','Do Not Call','Search','Magazine','Newspaper Article',
           'X Education Forums','Newspaper','Digital Advertisement',
           'Through Recommendations','Receive More Updates About Our Courses',
           'Update me on Supply Chain Content','Get updates on DM Content',
           'I agree to pay the amount through cheque',
           'A free copy of Mastering The Interview']

def binary_map(x):
    return x.map({'Yes':1,'No':0})

leads[varlist] = leads[varlist].apply(binary_map)

# %%
leads.head()
# Out:
#                Lead Origin     Lead Source  Do Not Email  Do Not Call  \
# 1                      API  Organic Search             0            0
# 2  Landing Page Submission  Direct Traffic             0            0
# 3  Landing Page Submission  Direct Traffic             0            0
# 4  Landing Page Submission          Google             0            0
# 6  Landing Page Submission          Google             0            0
#
#    Converted  TotalVisits  Total Time Spent on Website  Page Views Per Visit  \
# 1          0          5.0                          674                   2.5
# 2          1          2.0                         1532                   2.0
# 3          0          1.0                          305                   1.0
# 4          1          2.0                         1428                   1.0
# 6          1          2.0                         1640                   2.0
#
#        Last Activity Country  ... Through Recommendations  \
# ...

# %%
dummy = pd.get_dummies(leads[['Lead Origin','Lead Source']], drop_first=True)

# %%
dummy.head()
# Out:
#    Lead Origin_Landing Page Submission  Lead Origin_Lead Add Form  \
# 1                                False                      False
# 2                                 True                      False
# 3                                 True                      False
# 4                                 True                      False
# 6                                 True                      False
#
#    Lead Source_Facebook  Lead Source_Google  Lead Source_Olark Chat  \
# 1                 False               False                   False
# 2                 False               False                   False
# 3                 False               False                   False
# 4                 False                True                   False
# 6                 False                True                   False
#
#    Lead Source_Organic Search  Lead Source_Pay per Click Ads  \
# 1                        True                          False
# ...

# %%
leads = pd.concat([leads, dummy], axis=1)

# %%
leads.drop(['Lead Origin','Lead Source'], axis=1, inplace=True)

# %%
leads.head()
# Out:
#    Do Not Email  Do Not Call  Converted  TotalVisits  \
# 1             0            0          0          5.0
# 2             0            0          1          2.0
# 3             0            0          0          1.0
# 4             0            0          1          2.0
# 6             0            0          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit      Last Activity  \
# 1                          674                   2.5       Email Opened
# 2                         1532                   2.0       Email Opened
# 3                          305                   1.0        Unreachable
# 4                         1428                   1.0  Converted to Lead
# 6                         1640                   2.0       Email Opened
#
#   Country           Specialization How did you hear about X Education  ...  \
# 1   India                   Select                             Select  ...
# ...

# %%
varlist = ['Specialization','What is your current occupation','What matters most to you in choosing a course']

# %%
dummy = pd.get_dummies(leads[varlist], drop_first=True)

# %%
leads = pd.concat([leads, dummy], axis=1)

# %%
leads.drop(varlist, axis=1, inplace=True)

# %%
leads.head()
# Out:
#    Do Not Email  Do Not Call  Converted  TotalVisits  \
# 1             0            0          0          5.0
# 2             0            0          1          2.0
# 3             0            0          0          1.0
# 4             0            0          1          2.0
# 6             0            0          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit      Last Activity  \
# 1                          674                   2.5       Email Opened
# 2                         1532                   2.0       Email Opened
# 3                          305                   1.0        Unreachable
# 4                         1428                   1.0  Converted to Lead
# 6                         1640                   2.0       Email Opened
#
#   Country How did you hear about X Education  Search  ...  \
# 1   India                             Select       0  ...
# 2   India                             Select       0  ...
# ...

# %%
leads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4535 entries, 1 to 9239
# Data columns (total 64 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Do Not Email                                          4535 non-null   int64
#  1   Do Not Call                                           4535 non-null   int64
#  2   Converted                                             4535 non-null   int64
#  3   TotalVisits                                           4535 non-null   float64
#  4   Total Time Spent on Website                           4535 non-null   int64
#  5   Page Views Per Visit                                  4535 non-null   float64
#  6   Last Activity                                         4535 non-null   object
#  7   Country                                               4535 non-null   object
# ...

# %%
varlist = ['Last Activity','Country','Lead Profile']

# %%
dummy = pd.get_dummies(leads[varlist], drop_first=True)

# %%
leads = pd.concat([leads, dummy], axis=1)

# %%
leads.drop(varlist, axis=1, inplace=True)

# %%
leads.head()
# Out:
#    Do Not Email  Do Not Call  Converted  TotalVisits  \
# 1             0            0          0          5.0
# 2             0            0          1          2.0
# 3             0            0          0          1.0
# 4             0            0          1          2.0
# 6             0            0          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  \
# 1                          674                   2.5
# 2                         1532                   2.0
# 3                          305                   1.0
# 4                         1428                   1.0
# 6                         1640                   2.0
#
#   How did you hear about X Education  Search  Magazine  Newspaper Article  \
# 1                             Select       0         0                  0
# 2                             Select       0         0                  0
# 3                      Word Of Mouth       0         0                  0
# ...

# %%
leads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4535 entries, 1 to 9239
# Columns: 112 entries, Do Not Email to Lead Profile_Student of SomeSchool
# dtypes: bool(90), float64(2), int64(16), object(4)
# memory usage: 1.2+ MB

# %%
leads.select_dtypes(include=['object']).columns
# Out:
# Index(['How did you hear about X Education', 'Tags', 'City',
#        'Last Notable Activity'],
#       dtype='object')

# %%
varlist = ['How did you hear about X Education',
           'Tags',
           'City',
           'Last Notable Activity']

# %%
dummy = pd.get_dummies(leads[varlist], drop_first=True)

# %%
leads = pd.concat([leads, dummy], axis=1)

# %%
leads.drop(varlist, axis=1, inplace=True)

# %%
leads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4535 entries, 1 to 9239
# Columns: 161 entries, Do Not Email to Last Notable Activity_View in browser link Clicked
# dtypes: bool(143), float64(2), int64(16)
# memory usage: 1.3 MB

# %%
leads.select_dtypes(include=['object']).columns
# Out:
# Index([], dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
X = leads.drop('Converted', axis=1)
y = leads['Converted']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=100
)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train[['TotalVisits','Total Time Spent on Website','Page Views Per Visit']] = scaler.fit_transform(
    X_train[['TotalVisits','Total Time Spent on Website','Page Views Per Visit']]
)

# %%
import statsmodels.api as sm

# %%
logm1 = sm.GLM(y_train, sm.add_constant(X_train), family=sm.families.Binomial())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 logm1 = sm.GLM(y_train, sm.add_constant(X_train), family=sm.families.Binomial())
#
# File ~\anaconda3\Lib\site-packages\statsmodels\genmod\generalized_linear_model.py:326, in GLM.__init__(self, endog, exog, family, offset, exposure, freq_weights, var_weights, missing, **kwargs)
#     323 self.freq_weights = freq_weights
#     324 self.var_weights = var_weights
# --> 326 super().__init__(endog, exog, missing=missing,
#     327                           offset=offset, exposure=exposure,
#     328                           freq_weights=freq_weights,
#     329                           var_weights=var_weights, **kwargs)
#     330 self._check_inputs(family, self.offset, self.exposure, self.endog,
#     331                    self.freq_weights, self.var_weights)
#     332 if offset is None:
#
# ...

# %%
X_train = X_train.astype(int)

# %%
logm1 = sm.GLM(y_train, sm.add_constant(X_train), family=sm.families.Binomial())

# %%
res = logm1.fit()

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:              Converted   No. Observations:                 3174
# Model:                            GLM   Df Residuals:                     3036
# Model Family:                Binomial   Df Model:                          137
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -357.63
# Date:                Sat, 23 May 2026   Deviance:                       715.27
# Time:                        11:46:37   Pearson chi2:                 2.57e+03
# No. Iterations:                    28   Pseudo R-squ. (CS):             0.6799
# Covariance Type:            nonrobust
# ...
#                                                                coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
res.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                                              Results: Generalized linear model
# ...
# Model:                                   GLM                                 AIC:                               991.2682
# Link Function:                           Logit                               BIC:                               -23763.2344
# Dependent Variable:                      Converted                           Log-Likelihood:                    -357.63
# Date:                                    2026-05-23 11:47                    LL-Null:                           -2165.4
# No. Observations:                        3174                                Deviance:                          715.27
# Df Model:                                137                                 Pearson chi2:                      2.57e+03
# Df Residuals:                            3036                                Scale:                             1.0000
# ...

# %%
res.pvalues.sort_values(ascending=False).head(10)
# Out:
# Country_China                                    1.000000
# Country_Italy                                    1.000000
# Last Activity_Visited Booth in Tradeshow         0.999999
# Last Notable Activity_Email Link Clicked         0.999999
# Country_Kenya                                    0.999999
# Country_Tanzania                                 0.999999
# Lead Source_testone                              0.999999
# Newspaper                                        0.999999
# Last Notable Activity_Page Visited on Website    0.999999
# Lead Source_Facebook                             0.999999
# dtype: float64

# %%
col = ['Country_China',
       'Country_Italy',
       'Last Activity_Visited Booth in Tradeshow',
       'Last Notable Activity_Email Link Clicked',
       'Country_Kenya',
       'Country_Tanzania',
       'Lead Source_testone',
       'Newspaper',
       'Last Notable Activity_Page Visited on Website',
       'Lead Source_Facebook']

X_train = X_train.drop(col, axis=1)

# %%
logm1 = sm.GLM(y_train, sm.add_constant(X_train), family=sm.families.Binomial())
res = logm1.fit()
res.summary2()
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\statsmodels\genmod\families\links.py:198: RuntimeWarning: overflow encountered in exp
#   t = np.exp(-z)
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[75], line 2
#       1 logm1 = sm.GLM(y_train, sm.add_constant(X_train), family=sm.families.Binomial())
# ----> 2 res = logm1.fit()
#       3 res.summary2()
#
# File ~\anaconda3\Lib\site-packages\statsmodels\genmod\generalized_linear_model.py:1192, in GLM.fit(self, start_params, maxiter, method, tol, scale, cov_type, cov_kwds, use_t, full_output, disp, max_start_irls, **kwargs)
#    1190     if cov_type.lower() == 'eim':
#    1191         cov_type = 'nonrobust'
# -> 1192     return self._fit_irls(start_params=start_params, maxiter=maxiter,
#    1193                           tol=tol, scale=scale, cov_type=cov_type,
# ...

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression(max_iter=1000)
logreg.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 from sklearn.linear_model import LogisticRegression
#       3 logreg = LogisticRegression(max_iter=1000)
# ----> 4 logreg.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %%
leads.shape
# Out:
# (9240, 37)

# %%
leads = leads.drop(['Prospect ID','Lead Number'], axis=1)

# %%
leads.shape
# Out:
# (9240, 35)

# %%
leads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 35 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Lead Origin                                    9240 non-null   object
#  1   Lead Source                                    9204 non-null   object
#  2   Do Not Email                                   9240 non-null   object
#  3   Do Not Call                                    9240 non-null   object
#  4   Converted                                      9240 non-null   int64
#  5   TotalVisits                                    9103 non-null   float64
#  6   Total Time Spent on Website                    9240 non-null   int64
#  7   Page Views Per Visit                           9103 non-null   float64
#  8   Last Activity                                  9137 non-null   object
# ...

# %%
round(100*(leads.isnull().sum()/len(leads.index)),2).sort_values(ascending=False)
# Out:
# Lead Quality                                     51.59
# Asymmetrique Activity Index                      45.65
# Asymmetrique Activity Score                      45.65
# Asymmetrique Profile Score                       45.65
# Asymmetrique Profile Index                       45.65
# Tags                                             36.29
# What matters most to you in choosing a course    29.32
# Lead Profile                                     29.32
# What is your current occupation                  29.11
# Country                                          26.63
# How did you hear about X Education               23.89
# Specialization                                   15.56
# City                                             15.37
# Page Views Per Visit                              1.48
# TotalVisits                                       1.48
# Last Activity                                     1.11
# Lead Source                                       0.39
# ...

# %%
cols = ['Lead Quality',
        'Asymmetrique Activity Index',
        'Asymmetrique Activity Score',
        'Asymmetrique Profile Index',
        'Asymmetrique Profile Score',
        'Tags']

leads = leads.drop(cols, axis=1)

# %%
leads.shape
# Out:
# (9240, 29)

# %%
leads = leads.dropna()

# %%
leads.shape
# Out:
# (4925, 29)

# %%
round(100*(leads.isnull().sum()/len(leads.index)),2).sort_values(ascending=False)
# Out:
# Lead Origin                                      0.0
# Lead Source                                      0.0
# Do Not Email                                     0.0
# Do Not Call                                      0.0
# Converted                                        0.0
# TotalVisits                                      0.0
# Total Time Spent on Website                      0.0
# Page Views Per Visit                             0.0
# Last Activity                                    0.0
# Country                                          0.0
# Specialization                                   0.0
# How did you hear about X Education               0.0
# What is your current occupation                  0.0
# What matters most to you in choosing a course    0.0
# Search                                           0.0
# Magazine                                         0.0
# Newspaper Article                                0.0
# X Education Forums                               0.0
# ...

# %%
leads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4925 entries, 1 to 9239
# Data columns (total 29 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Lead Origin                                    4925 non-null   object
#  1   Lead Source                                    4925 non-null   object
#  2   Do Not Email                                   4925 non-null   object
#  3   Do Not Call                                    4925 non-null   object
#  4   Converted                                      4925 non-null   int64
#  5   TotalVisits                                    4925 non-null   float64
#  6   Total Time Spent on Website                    4925 non-null   int64
#  7   Page Views Per Visit                           4925 non-null   float64
#  8   Last Activity                                  4925 non-null   object
# ...

# %%
varlist = ['Lead Origin',
           'Lead Source',
           'Do Not Email',
           'Do Not Call',
           'Last Activity',
           'Country',
           'Specialization',
           'How did you hear about X Education',
           'What is your current occupation',
           'What matters most to you in choosing a course',
           'Search',
           'Magazine',
           'Newspaper Article',
           'X Education Forums',
           'Newspaper',
           'Digital Advertisement',
           'Through Recommendations',
           'Receive More Updates About Our Courses',
           'Update me on Supply Chain Content',
           'Get updates on DM Content',
           'Lead Profile',
           'City',
           'I agree to pay the amount through cheque',
           'A free copy of Mastering The Interview',
           'Last Notable Activity']

# %%
dummy = pd.get_dummies(leads[varlist], drop_first=True)

# %%
leads = pd.concat([leads, dummy], axis=1)

# %%
leads = leads.drop(varlist, axis=1)

# %%
leads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4925 entries, 1 to 9239
# Columns: 132 entries, Converted to Last Notable Activity_View in browser link Clicked
# dtypes: bool(128), float64(2), int64(2)
# memory usage: 808.0 KB

# %%
X = leads.drop('Converted', axis=1)
y = leads['Converted']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=100
)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train[['TotalVisits','Total Time Spent on Website','Page Views Per Visit']] = scaler.fit_transform(
    X_train[['TotalVisits','Total Time Spent on Website','Page Views Per Visit']]
)

# %%
X_train[['TotalVisits','Total Time Spent on Website','Page Views Per Visit']] = scaler.fit_transform(
    X_train[['TotalVisits','Total Time Spent on Website','Page Views Per Visit']]
)

# %%
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = logreg.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.4506089309878214

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.00      0.00       813
#            1       0.45      1.00      0.62       665
#
#     accuracy                           0.45      1478
#    macro avg       0.73      0.50      0.31      1478
# weighted avg       0.75      0.45      0.28      1478

# %%
logreg = LogisticRegression(max_iter=1000, class_weight='balanced')

# %%
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000)

# %%
y_pred = logreg.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.44993234100135315

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[  0, 813],
#        [  0, 665]])

# %% [markdown]
# Conclusion:
# The Logistic Regression model was successfully implemented on the Leads dataset.
# Data preprocessing techniques such as handling missing values, encoding categorical variables, scaling and train-test splitting were performed sucessfully.
# The model achieved an accuracy of approximately 45% on the test data.
# Model evaluation was carried out using accuracy score, classification report, and confusion matrix.
